# %%
import os
import subprocess

# %%
project_folder = r"C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)"

clean_folder = os.path.join(project_folder, "Data", "Clean_Proteins")

pdbqt_folder = os.path.join(project_folder, "Data", "PDBQT_Proteins")

os.makedirs(pdbqt_folder, exist_ok=True)

# %%
import os

base = r"C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data"

folders = [
    "Structures",
    "Clean_Proteins",
    "PDBQT_Proteins"
]

for folder in folders:
    path = os.path.join(base, folder)
    print("\n", folder)
    print("-"*40)
    if os.path.exists(path):
        print(os.listdir(path))
    else:
        print("Folder not found!")
# Out:
#  Structures
# ----------------------------------------
# ['SDHB.pdb.gz']
#
#  Clean_Proteins
# ----------------------------------------
# ['1NEN_clean.pdb', '1Y8P_clean.pdb', '2H89_clean.pdb', '6C12_clean.pdb']
#
#  PDBQT_Proteins
# ----------------------------------------
# ['2H89.pdbqt', '6C12.pdbqt']

# %%
import os

# Base project folder
base = r"C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data"

# Project folders
structures_folder = os.path.join(base, "Structures")
clean_folder = os.path.join(base, "Clean_Proteins")
pdbqt_folder = os.path.join(base, "PDBQT_Proteins")
ligands_folder = os.path.join(base, "Ligands")
results_folder = os.path.join(base, "Results")

print("Structures :", structures_folder)
print("Clean Proteins :", clean_folder)
print("PDBQT Proteins :", pdbqt_folder)
print("Ligands :", ligands_folder)
print("Results :", results_folder)
# Out:
# Structures : C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\Structures
# Clean Proteins : C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\Clean_Proteins
# PDBQT Proteins : C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\PDBQT_Proteins
# Ligands : C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\Ligands
# Results : C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\Results

# %%
protein = "6C12"

input_file = os.path.join(clean_folder, protein + "_clean.pdb")
output_file = os.path.join(pdbqt_folder, protein + ".pdbqt")

print(input_file)
print(output_file)
# Out:
# C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\Clean_Proteins\6C12_clean.pdb
# C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\PDBQT_Proteins\6C12.pdbqt

# %%
import os

base = r"C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data"

print(os.listdir(os.path.join(base, "PDBQT_Proteins")))
# Out:
# ['2H89.pdbqt', '6C12.pdbqt']

# %%
import os

base = r"C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data"
clean_folder = os.path.join(base, "Clean_Proteins")

for file in os.listdir(clean_folder):
    print(file)
# Out:
# 1NEN_clean.pdb
# 1Y8P_clean.pdb
# 2H89_clean.pdb
# 6C12_clean.pdb

# %%
import os

folder = r"C:\Users\sofiya chavarekar\OneDrive\Assignment- Module 1\PROJECT(AI-based drug target identification for SDH-related rare disorders)\Data\PDBQT_Proteins"

print(os.listdir(folder))
# Out:
# ['2H89.pdbqt', '6C12.pdbqt']
